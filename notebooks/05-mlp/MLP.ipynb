# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # Multi layer Perceptron
#
# All figures are from Chapter 3 of UDLBook.
# https://github.com/udlbook/udlbook

# %% [markdown]
# ## Recall the single layer perceptron

# %% [markdown]
# ![image.png](attachment:ce50c61c-a8b5-4fe1-b762-bd6deaacc43b.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png)

# %% [markdown]
# $\newcommand{\bfx}{\mathbf{x}}$
# $\newcommand{\bfw}{\mathbf{w}}$
# $\newcommand{\bfW}{\mathbf{W}}$
# $$ l = f(\bfx) = \bfw^\top \bfx + w_0 $$

# %% [markdown]
# ## Multi Layer Perceptrons

# %% [markdown]
# ReLU activation function $\text{ReLU}(z) = \max\{ 0, z \}$

# %% [markdown]
# ![image.png](attachment:eddf9eb9-ff9a-4c00-9df3-d1b354a850d5.png)

# %% [markdown]
# ## Two layer Perceptron

# %% [markdown]
# $$ y = f(\bfx) = \text{Linear}(\text{ Activation_function}( \text{ Linear} (x)))$$

# %% [markdown]
# ![image.png](attachment:06d24047-4626-42a4-8e17-eec4dfcaf79e.png)

# %% [markdown]
# ### Example
#
# $$ a(x) = \text{ReLU}(x) $$
# $$ h_1 = a(\theta_{10} + \theta_{11} x) $$
# $$ h_2 = a(\theta_{20} + \theta_{21} x) $$
# $$ h_3 = a(\theta_{30} + \theta_{31} x) $$
# $$ y = \phi_0 + \phi_1 h_1 + \phi_2 h_2 + \phi_3 h_3 $$

# %% [markdown]
# ![image.png](attachment:c259ca08-947c-4b88-ad32-033e1c027ccc.png)

# %% [markdown]
# ## Depicting Neural Networks

# %% [markdown]
# ![image.png](attachment:42ac4c48-87ca-4a3f-bf49-45511ef3154a.png)

# %% [markdown]
# ## Universal Approximation Theorem

# %% [markdown]
# ![image.png](attachment:0923a78d-cb7a-4223-8af3-37fdb30f4c32.png)

# %% [markdown]
# ## Multivariate outputs

# %% [markdown]
# ![image.png](attachment:68cba13c-42e7-474b-8238-c214a00c010f.png)

# %% [markdown]
# ![image.png](attachment:e538c122-9373-471b-96f4-20a08aa7b5a6.png)

# %% [markdown]
# ![image.png](attachment:c01bba88-fbfc-445f-91c8-647cf0f1d624.png)

# %% [markdown]
# ![image.png](attachment:bff0401a-5d58-4480-af7d-9ced1d89db26.png)

# %% [markdown]
# ## Activation functions

# %% [markdown]
# ![image.png](attachment:d0560fb2-6a21-4f6b-8b22-1875f80da7f0.png)
